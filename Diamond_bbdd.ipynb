# %%
#pip install duckdb

#%pip install sqlite-database
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports

import numpy as np
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt   # conda install matplotlib

# seaborn
import seaborn as sns  

pd.options.mode.copy_on_write = True 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

from sklearn.impute import SimpleImputer

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

from collections import Counter
from sklearn.datasets import make_classification

from imblearn.over_sampling import SMOTE


import sqlite3
import duckdb

# %%
# Create database connection and .db file

conn = sqlite3.connect('data/diamonds_train.db')

cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()

print(tables)

# Lista para almacenar los DataFrames

dataframes = []

# Cargar y convertir los datos de cada tabla en un DataFrame
for table in tables:
    table_name = table[0]
    print(f"Cargando datos de la tabla: {table_name}")

df_diamonds_dimensions = pd.read_sql_query(f"SELECT * FROM diamonds_dimensions", conn)
df_diamonds_transactional = pd.read_sql_query(f"SELECT * FROM diamonds_transactional", conn)
df_diamonds_properties = pd.read_sql_query(f"SELECT * FROM diamonds_properties", conn)
df_diamonds_cut = pd.read_sql_query(f"SELECT * FROM diamonds_cut", conn)
df_diamonds_color = pd.read_sql_query(f"SELECT * FROM diamonds_color", conn)
df_diamonds_clarity = pd.read_sql_query(f"SELECT * FROM diamonds_clarity", conn)
df_diamonds_city = pd.read_sql_query(f"SELECT * FROM diamonds_city", conn)

# Cerrar la conexión
conn.close()
# Out:
# [('diamonds_dimensions',), ('diamonds_transactional',), ('diamonds_properties',), ('diamonds_cut',), ('diamonds_color',), ('diamonds_clarity',), ('diamonds_city',)]
# Cargando datos de la tabla: diamonds_dimensions
# Cargando datos de la tabla: diamonds_transactional
# Cargando datos de la tabla: diamonds_properties
# Cargando datos de la tabla: diamonds_cut
# Cargando datos de la tabla: diamonds_color
# Cargando datos de la tabla: diamonds_clarity
# Cargando datos de la tabla: diamonds_city

# %%
diamonds_df = pd.merge(df_diamonds_transactional, df_diamonds_city) 

diamonds_df.head()
# Out:
#                                             index_id  price  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
#
#                                              city_id  carat       city
# 0  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# 1  89c7286890f7347ab235234e74d406596a127ae3679042...   0.32   Kimberly
# 2  2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...   0.71  Las Vegas
# 3  89c7286890f7347ab235234e74d406596a127ae3679042...   0.41   Kimberly
# 4  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.02      Dubai

# %%
diamonds_df = pd.merge(diamonds_df, df_diamonds_properties)

diamonds_df.head()
# Out:
#                                             index_id  price  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
#
#                                              city_id  carat       city  \
# 0  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# 1  89c7286890f7347ab235234e74d406596a127ae3679042...   0.32   Kimberly
# 2  2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...   0.71  Las Vegas
# 3  89c7286890f7347ab235234e74d406596a127ae3679042...   0.41   Kimberly
# 4  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.02      Dubai
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# ...

# %%
diamonds_df = pd.merge(diamonds_df, df_diamonds_color)

diamonds_df.head()
# Out:
#                                             index_id  price  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2  d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3  4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4  4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
#
#                                              city_id  carat       city  \
# 0  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# 1  89c7286890f7347ab235234e74d406596a127ae3679042...   0.32   Kimberly
# 2  2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...   0.71  Las Vegas
# 3  89c7286890f7347ab235234e74d406596a127ae3679042...   0.41   Kimberly
# 4  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.02      Dubai
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# ...

# %%
diamonds_df = pd.merge(diamonds_df, df_diamonds_cut)

diamonds_df
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat       city  \
# 0      6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# ...

# %%
diamonds_df = pd.merge(diamonds_df, df_diamonds_clarity)

diamonds_df
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat       city  \
# 0      6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# ...

# %%
diamonds_df = pd.merge(diamonds_df, df_diamonds_dimensions)

diamonds_df
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat       city  \
# 0      6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.21      Dubai
# ...

# %%
diamonds_df = diamonds_df.drop(['index_id', 'city_id', 'cut_id', 'color_id', 'clarity_id'], axis=1)

diamonds_df
# Out:
#        price  carat       city color        cut clarity  depth  table     x  \
# 0       4268   1.21      Dubai     J    Premium     VS2   62.4   58.0  6.83
# 1        505   0.32   Kimberly     H  Very Good     VS2   63.0   57.0  4.35
# 2       2686   0.71  Las Vegas     G       Fair     VS1   65.5   55.0  5.62
# 3        738   0.41   Kimberly     D       Good     SI1   63.8   56.0  4.68
# 4       4882   1.02      Dubai     G      Ideal     SI1   60.5   59.0  6.55
# ...      ...    ...        ...   ...        ...     ...    ...    ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal     VS1   62.7   57.0  7.10
# 40451  12615   2.02     Madrid     F       Good     SI2   57.1   60.0  8.31
# 40452   5457   1.01   Kimberly     H      Ideal     SI1   62.7   56.0  6.37
# 40453    456   0.33   Kimberly     J      Ideal     VS1   61.9   54.3  4.45
# 40454   6232   1.24     London     I      Ideal     SI1   62.0   58.0  6.83
#
#           y     z
# 0      6.79  4.25
# ...

# %%
# Guardamos el dataframe en un nuevo csv

diamonds_df.to_csv('data/diamonds_train.csv')
